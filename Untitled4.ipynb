# %% [markdown]
# <a href="https://colab.research.google.com/github/speranzadeejoe/Parkinson-s-Disease-Progression-Prediction-Using-Feedforward-Neural-Network/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aniruddhawankhede/parkinsons-disease-progression-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/parkinsons-disease-progression-dataset

# %%
import os

# List files in the extracted directory to find the correct filename
print(os.listdir(path))
# Out:
# ['parkinsons_disease_progression_500.csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(path + "/parkinsons_disease_progression_500.csv")
df.head()
# Out:
#    Patient_ID  Age Gender  Years_Since_Diagnosis  UPDRS_Score  \
# 0           1   78      M                      5           41
# 1           2   64      F                      3           52
# 2           3   57      M                      5           21
# 3           4   70      F                      5           19
# 4           5   68      M                      5           57
#
#    Tremor_Severity  Motor_Function  Speech_Difficulty  Balance_Problems  \
# 0                3               2                  2                 3
# 1                4               1                  2                 3
# 2                1               0                  0                 5
# 3                4               1                  3                 1
# 4                3               0                  4                 3
#
#   Medications Exercise_Level  Disease_Progression
# 0    Levodopa       Moderate                    2
# 1  Amantadine            Low                    2
# ...

# %%
df.tail(5)
# Out:
#      Patient_ID  Age Gender  Years_Since_Diagnosis  UPDRS_Score  \
# 495         496   70      F                      1           20
# 496         497   65      M                      9           42
# 497         498   70      F                      9           43
# 498         499   60      M                      5           40
# 499         500   84      M                      4           39
#
#      Tremor_Severity  Motor_Function  Speech_Difficulty  Balance_Problems  \
# 495                5               0                  0                 3
# 496                4               4                  2                 0
# 497                4               3                  2                 4
# 498                3               2                  1                 1
# 499                1               5                  3                 3
#
#      Medications Exercise_Level  Disease_Progression
# 495   Ropinirole           High                    2
# ...

# %%
df.shape
# Out:
# (500, 12)

# %%
df.isnull().sum()
# Out:
# Patient_ID               0
# Age                      0
# Gender                   0
# Years_Since_Diagnosis    0
# UPDRS_Score              0
# Tremor_Severity          0
# Motor_Function           0
# Speech_Difficulty        0
# Balance_Problems         0
# Medications              0
# Exercise_Level           0
# Disease_Progression      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Patient_ID         Age  Years_Since_Diagnosis  UPDRS_Score  \
# count  500.000000  500.000000             500.000000   500.000000
# mean   250.500000   67.846000               5.030000    36.652000
# std    144.481833   10.427644               2.631911    12.796186
# min      1.000000   50.000000               1.000000    15.000000
# 25%    125.750000   58.000000               3.000000    26.000000
# 50%    250.500000   69.000000               5.000000    36.500000
# 75%    375.250000   77.000000               7.000000    47.000000
# max    500.000000   84.000000               9.000000    59.000000
#
#        Tremor_Severity  Motor_Function  Speech_Difficulty  Balance_Problems  \
# count       500.000000       500.00000         500.000000        500.000000
# mean          2.564000         2.56600           2.552000          2.492000
# std           1.680343         1.70042           1.696187          1.723914
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             500 non-null    int64
#  1   Age                    500 non-null    int64
#  2   Gender                 500 non-null    object
#  3   Years_Since_Diagnosis  500 non-null    int64
#  4   UPDRS_Score            500 non-null    int64
#  5   Tremor_Severity        500 non-null    int64
#  6   Motor_Function         500 non-null    int64
#  7   Speech_Difficulty      500 non-null    int64
#  8   Balance_Problems       500 non-null    int64
#  9   Medications            500 non-null    object
#  10  Exercise_Level         500 non-null    object
#  11  Disease_Progression    500 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 47.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.boxplot(df['Age'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Years_Since_Diagnosis'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['UPDRS_Score'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Tremor_Severity'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Motor_Function'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Speech_Difficulty'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Balance_Problems'])
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(df['Disease_Progression'])
plt.show()

# %%
df.drop('Patient_ID', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age Gender  Years_Since_Diagnosis  UPDRS_Score  Tremor_Severity  \
# 0   78      M                      5           41                3
# 1   64      F                      3           52                4
# 2   57      M                      5           21                1
# 3   70      F                      5           19                4
# 4   68      M                      5           57                3
#
#    Motor_Function  Speech_Difficulty  Balance_Problems Medications  \
# 0               2                  2                 3    Levodopa
# 1               1                  2                 3  Amantadine
# 2               0                  0                 5  Amantadine
# 3               1                  3                 1  Amantadine
# 4               0                  4                 3  Ropinirole
#
#   Exercise_Level  Disease_Progression
# 0       Moderate                    2
# 1            Low                    2
# 2            Low                    2
# ...

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Age'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['Gender'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    500 non-null    int64
#  1   Gender                 500 non-null    object
#  2   Years_Since_Diagnosis  500 non-null    int64
#  3   UPDRS_Score            500 non-null    int64
#  4   Tremor_Severity        500 non-null    int64
#  5   Motor_Function         500 non-null    int64
#  6   Speech_Difficulty      500 non-null    int64
#  7   Balance_Problems       500 non-null    int64
#  8   Medications            500 non-null    object
#  9   Exercise_Level         500 non-null    object
#  10  Disease_Progression    500 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 43.1+ KB

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Encode categorical variables
le_gender = LabelEncoder()
df['Gender'] = le_gender.fit_transform(df['Gender'])

le_med = LabelEncoder()
df['Medications'] = le_med.fit_transform(df['Medications'])

le_exercise = LabelEncoder()
df['Exercise_Level'] = le_exercise.fit_transform(df['Exercise_Level'])

# Define features and target
X = df.drop('Disease_Progression', axis=1)
y = df['Disease_Progression']

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build FNN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)  # Output layer for regression
])

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Train model
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=16, verbose=1)

# Evaluate on test set
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"\nTest MAE: {test_mae:.3f}")
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.6321 - mae: 1.7035 - val_loss: 1.6887 - val_mae: 1.0534
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4707 - mae: 1.0137 - val_loss: 0.8270 - val_mae: 0.7585
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8632 - mae: 0.7977 - val_loss: 0.7916 - val_mae: 0.7481
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7675 - mae: 0.7461 - val_loss: 0.7876 - val_mae: 0.7624
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6899 - mae: 0.7058 - val_loss: 0.8073 - val_mae: 0.7719
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6406 - mae: 0.6645 - val_loss: 0.8093 - val_mae: 0.7775
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6046 - mae: 0.6556 - val_loss: 0.8118 - val_mae: 0.7799
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6051 - mae: 0.6474 - val_loss: 0.8112 - val_mae: 0.7792
# Epoch 9/100
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Predict on the test set
y_pred = model.predict(X_test).flatten()

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the report
print("📊 Regression Report:")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
print(f"R² Score: {r2:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 📊 Regression Report:
# Mean Absolute Error (MAE): 0.908
# Mean Squared Error (MSE): 1.247
# Root Mean Squared Error (RMSE): 1.117
# R² Score: -0.694

# %%
# --- 📈 Plot Epoch Graph (Loss and MAE) ---
plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Val Loss', color='red')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()

# MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE', color='green')
plt.plot(history.history['val_mae'], label='Val MAE', color='orange')
plt.title('Model MAE over Epochs')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()
plt.show()
